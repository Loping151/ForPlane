# %%
import torch
import os
import cv2
import matplotlib.pyplot as plt
bdir = '../data/endonerf_full_datasets/cutting_tissues_twice'
ist = torch.load(os.path.join(bdir, 'ist_weights_masked.pt'))
ist = ist.reshape((156,512,-1)).numpy()

# %%
# def normalize(x):
#     return (x - x.min()) / (x.max() - x.min())

# for i in range(156):
#     img = (normalize(ist[26])*255).astype('uint8')
#     # use colormap
#     img = cv2.applyColorMap(img, cv2.COLORMAP_JET)
#     # show image, note that the image is in BGR format
#     cv2.imwrite(os.path.join(bdir, 'sample_weights', str(i)+'.png'), img)
#     plt.imshow(img)
#     break


for i in range(156):
    plt.imshow(ist[i])
    plt.axis('off')
    plt.savefig(os.path.join(bdir, 'sample_weights', str(i)+'.png'), transparent = True)

# %%
ist[i]
# Out:
# array([[3.6616296e-08, 3.5881033e-08, 3.6469242e-08, ..., 3.2204696e-08,
#         3.2645854e-08, 3.2498800e-08],
#        [3.4557551e-08, 3.4851656e-08, 3.5292818e-08, ..., 3.1763534e-08,
#         3.2351750e-08, 3.2498800e-08],
#        [3.2351750e-08, 3.2939962e-08, 3.3087016e-08, ..., 3.1322376e-08,
#         3.2057642e-08, 3.2498800e-08],
#        ...,
#        [1.9558103e-08, 1.9558103e-08, 1.9558103e-08, ..., 5.7203778e-08,
#         5.7497878e-08, 5.7791986e-08],
#        [1.8087569e-08, 1.8087569e-08, 1.8087569e-08, ..., 5.6762616e-08,
#         5.7350828e-08, 5.7791986e-08],
#        [1.7499355e-08, 1.7499355e-08, 1.7499355e-08, ..., 5.5880292e-08,
#         5.6174400e-08, 5.7056717e-08]], dtype=float32)
